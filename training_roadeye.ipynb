# %%
import torch
import torchvision
from torchvision import datasets, models, transforms
import matplotlib.pyplot as plt
import torch.nn as nn 
import torch.optim as optim
from torch.optim import lr_scheduler
import numpy as np
import torch.backends.cudnn as cudnn
from PIL import Image
from tempfile import TemporaryDirectory

cudnn.benchmark = True
plt.ion()

# To know which device gpu or cpu the code is going to run on
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")

# ===========================================================================
#                        Data Preprocessing & AUGMENTATION
# ===========================================================================

# Data preprocessing will involve data augmentation and normalization for training
# But for validation we will only perform normalization

data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((360, 640)), # Reduce the resolution of the images from 1280x720 to 640x360 for faster training
        # HorizontalFlip
        # Color jitter
        # Gausian Blur
        # Noise
        # RandomRotations
        transforms.ToTensor(), # Convert PIL image or numpy.ndarray to tensor
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # To match the normalization of the resnet backbone.
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(), # Convert PIL image or numpy.ndarray to tensor
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # To match the normalization of the resnet backbone.
    ]),
}
# Out:
# Using cuda device
